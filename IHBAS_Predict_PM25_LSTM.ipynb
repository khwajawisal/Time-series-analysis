# %% [markdown]
# ### Link Colab to Google Drive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# drive/  sample_data/

# %%
import os
os.chdir("drive/My Drive/Adil_Work/")
os.listdir()
# Out:
# ['input',
#  'output',
#  'DWARKA_PM2-5_Predict_LSTM.ipynb',
#  'IHBAS_Predict_PM25_LSTM.ipynb']

# %% [markdown]
# # Steps:
#
# * Importing dependencies & Declaring methods and variables
# * Reading and analyzing data. (Pandas)
# * Normalizing the data. (SkLearn)
# * Converting data to time-series and supervised learning problem.
# * Creating model (Keras)

# %% [markdown]
# ## Importing dependencies & Declaring methods and variables

# %%
import numpy as np
import os
import sys
import time
import pandas as pd 
from matplotlib import pyplot as plt
from tqdm._tqdm_notebook import tqdm_notebook
import pickle
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras import optimizers
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
params = {
    "batch_size": 10,
    "epochs": 100,
    "lr": 0.0001,
    "time_steps": 60   #length of input, or No of days when concidering Stock prices
}

project_path = os.getcwd()
INPUT_PATH = "input/"
OUTPUT_PATH = "output/"
TIME_STEPS = params["time_steps"]
BATCH_SIZE = params["batch_size"]

# %%
# trims the dataset so that the entire DS is in multiples of batch size(20 is this case)
# some left out rows from DS are discarded after this.

def trim_dataset(mat,batch_size):
    """
    trims dataset to a size that's divisible by BATCH_SIZE
    """
    no_of_rows_drop = mat.shape[0]%batch_size
    if no_of_rows_drop > 0:
        return mat[:-no_of_rows_drop]
    else:
        return mat


def build_timeseries(mat, y_col_index):
    """
    Converts ndarray into timeseries format and supervised data format. Takes first TIME_STEPS
    number of rows as input and sets the TIME_STEPS+1th data as corresponding output and so on.
    :param mat: ndarray which holds the dataset
    :param y_col_index: index of column which acts as output
    :return: returns two ndarrays-- input and output in format suitable to feed
    to LSTM.
    """
    # total number of time-series samples would be len(mat) - TIME_STEPS
    dim_0 = mat.shape[0] - TIME_STEPS
    dim_1 = mat.shape[1]
    x = np.zeros((dim_0, TIME_STEPS, dim_1))
    y = np.zeros((dim_0,))
    for i in tqdm_notebook(range(dim_0)):
        x[i] = mat[i:TIME_STEPS+i]
        y[i] = mat[TIME_STEPS+i, y_col_index]
    return x, y

# %% [markdown]
# ## Reading and analyzing data. (Pandas)

# %%
# !ls
# !pwd
# Out:
# DWARKA_PM2-5_Predict_LSTM.ipynb  IHBAS_Predict_PM25_LSTM.ipynb	input  output
# /content/drive/My Drive/Adil_Work

# %%
df_ge = pd.read_csv(os.path.join(INPUT_PATH, "IHBAS_DataSheet_01.csv"), engine='python')
print("Dataset size: ", df_ge.shape)
print("Columns: ", df_ge.columns)
display(df_ge.head(5))

plt.figure(figsize=(15,10))
plt.plot(df_ge["AT"])
plt.plot(df_ge["BP"])
plt.plot(df_ge["RH"])
plt.plot(df_ge["SR"])
plt.plot(df_ge["VWS"])
plt.plot(df_ge["VD"])
plt.plot(df_ge["WS"])
plt.plot(df_ge["CO"])
plt.plot(df_ge["NO"])
plt.plot(df_ge["NH3"])
plt.plot(df_ge["PM2.5"])
plt.title('PM 2.5 Data Chart')
plt.ylabel('PM 2.5 Value')
plt.xlabel('Days')
plt.legend(['AT', 'BP', 'RH', 'SR', 'VWS', 'VD', 'WS', 'CO', 'NO', 'NH3','PM2.5'], loc='upper left')
plt.show()
# Out:
# Dataset size:  (986, 11)
# Columns:  Index(['AT', 'BP', 'RH', 'SR', 'VWS', 'VD', 'WS', 'CO', 'NO', 'NH3', 'PM2.5'], dtype='object')
#       AT      BP     RH     SR   VWS      VD    WS    CO     NO    NH3   PM2.5
# 0  28.72  752.65  36.80  88.54 -0.01  263.59  1.00  0.63   5.15  24.95  103.58
# 1  26.21  752.70  55.65  75.65 -0.01  177.37  0.98  1.08  13.30  31.88  147.75
# 2  24.83  752.62  42.73  77.51 -0.01  172.48  1.07  0.76   9.76  32.35  155.53
# 3  23.81  752.32  47.39  75.31 -0.01  165.29  1.05  0.83  11.36  30.66  201.95
# 4  25.09  751.72  46.31  72.19 -0.01  149.15  1.03  1.02   8.84  38.51  202.08

# %% [markdown]
# ## Normalizing the data. (SkLearn)
# The data is not normalized and the range for each column varies, especially Volume. Normalizing data helps the algorithm in converging i.e. to find local/ global minimum efficiently.

# %%
df_train, df_test = train_test_split(df_ge, train_size=0.85, test_size=0.15, shuffle=False)
print("Train--Test size", len(df_train), len(df_test))

# scale the feature MinMax, build array
train_cols = ["AT", "BP", "RH", "SR", "VWS", "VD", "WS", "CO", "NO", "NH3",
       "PM2.5"]  # training feautres
x = df_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler()

x_train = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.transform(df_test.loc[:,train_cols])
#print(x_train[:,0])

#display(x_train[0])
# Out:
# Train--Test size 838 148

# %%
print("Deleting unused dataframes of total size(KB)",(sys.getsizeof(df_ge)+sys.getsizeof(df_train)+sys.getsizeof(df_test))//1024)
del df_ge, df_test, df_train, x

print("Are any NaNs present in train/test matrices?",np.isnan(x_train).any(), np.isnan(x_train).any())
# Out:
# Deleting unused dataframes of total size(KB) 177
# Are any NaNs present in train/test matrices? False False

# %% [markdown]
# ## Converting data to time-series and supervised learning problem.
#
# LSTMs consume input in format [ batch_size, time_steps, Features ] as a 3- dimensional array.
#
# * Batch Size says how many samples of input do you want your Neural Net to see before updating the weights. So let’s say you have 100 samples (input dataset) and you want to update weights every time your NN has seen an input. In that case batch size would be 1 and total number of batches would be 100. Like wise if you wanted your network to update weights after it has seen all the samples, batch size would be 100 and number of batches would be 1. As it turns out using very small batch size reduces the speed of training and on the other hand using too big batch size (like whole dataset) reduces the models ability to generalize to different data and it also consumes more memory. But it takes fewer steps to find the minima for your objective function. So you have to try out various values on your data and find the sweet spot. It’s quite a big topic.
# * Time Steps define how many units back in time you want your network to see. For example if you were working on a character prediction problem where you have a text corpus to train on and you decide to feed your network 6 characters at a time. Then your time step is 6. In our case we will be using 60 as time step i.e. we will look into 2 months of data to predict next day's price.
# * Features is the number of attributes used to represent each time step. Consider the character prediction example above, and assume that you use a one-hot encoded vector of size 100 to represent each character. Then feature size here is 100. In our case we will use 5 as the number of attributes.

# %%
# 3rd col (Close value ) is the target for this dataset

x_t, y_t = build_timeseries(x_train, 10)
x_t = trim_dataset(x_t, BATCH_SIZE)
y_t = trim_dataset(y_t, BATCH_SIZE)
print("Train size",x_t.shape, y_t.shape)

x_temp, y_temp = build_timeseries(x_test, 10)
x_val, x_test_t = np.split(trim_dataset(x_temp, BATCH_SIZE),2)
y_val, y_test_t = np.split(trim_dataset(y_temp, BATCH_SIZE),2)

print("Test size", x_test_t.shape, y_test_t.shape)
print("Val size", x_val.shape, y_val.shape)
# Out:
# HBox(children=(IntProgress(value=0, max=778), HTML(value='')))
# Train size (770, 60, 11) (770,)
# HBox(children=(IntProgress(value=0, max=88), HTML(value='')))
# Test size (40, 60, 11) (40,)
# Val size (40, 60, 11) (40,)

# %% [markdown]
# ## Creating model (Keras)

# %%
x_t.shape
# Out:
# (520, 60, 13)

# %%
def create_model():
    lstm_model = Sequential()
    lstm_model.add(LSTM(80, batch_input_shape=(BATCH_SIZE, TIME_STEPS, x_t.shape[2]),
                        dropout=0.0, recurrent_dropout=0.0, stateful=True, return_sequences=True,
                        kernel_initializer='random_uniform'))
    lstm_model.add(Dropout(0.4))
    lstm_model.add(LSTM(80, dropout=0.0))
    lstm_model.add(Dropout(0.4))   
    lstm_model.add(Dense(256,activation='relu'))
    lstm_model.add(Dropout(0.5))    
    lstm_model.add(Dense(128,activation='relu'))
    lstm_model.add(Dropout(0.5))
    lstm_model.add(Dense(1,activation='sigmoid'))
    optimizer = optimizers.RMSprop(lr=params["lr"])
    lstm_model.compile(loss='mean_squared_error', optimizer=optimizer)
    return lstm_model

# %%
#Load a model if already created and dumped in a pickle file

model = None
try:
    model = pickle.load(open("lstm_model", 'rb'))
    print("Loaded saved model...")
except FileNotFoundError:
    print("Model not found")
# Out:
# Model not found

# %% [markdown]
# ### Model Training

# %%
is_update_model = True
if model is None or is_update_model:
    print("Building model...")
    
    model = create_model()
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
                       patience=40, min_delta=0.0001)
    
    mcp = ModelCheckpoint(os.path.join(OUTPUT_PATH,
                          "best_model.h5"), monitor='val_loss', verbose=1,
                          save_best_only=True, save_weights_only=False, mode='min', period=1)
    
    csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'training_log_' + time.ctime().replace(" ","_") + '.log'), append=True)
    
    history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=BATCH_SIZE,
                        shuffle=False, validation_data=(trim_dataset(x_val, BATCH_SIZE),
                        trim_dataset(y_val, BATCH_SIZE)), callbacks=[es, mcp, csv_logger])
    
    print("saving model...")
    pickle.dump(model, open(os.path.join(OUTPUT_PATH, "lstm_model"), "wb"))
# Out:
# Building model...
# W0706 13:13:56.329403 140290053187456 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0706 13:13:56.623597 140290053187456 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0706 13:13:57.414094 140290053187456 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 770 samples, validate on 40 samples
# Epoch 1/100
#  - 5s - loss: 0.0894 - val_loss: 0.0122
#
# Epoch 00001: val_loss improved from inf to 0.01215, saving model to output/best_model.h5
# Epoch 2/100
#  - 4s - loss: 0.0065 - val_loss: 0.0123
#
# Epoch 00002: val_loss did not improve from 0.01215
# Epoch 3/100
#  - 4s - loss: 0.0069 - val_loss: 0.0122
#
# Epoch 00003: val_loss did not improve from 0.01215
# Epoch 4/100
#  - 4s - loss: 0.0066 - val_loss: 0.0124
#
# Epoch 00004: val_loss did not improve from 0.01215
# Epoch 5/100
#  - 4s - loss: 0.0064 - val_loss: 0.0122
#
# Epoch 00005: val_loss did not improve from 0.01215
# Epoch 6/100
#  - 4s - loss: 0.0065 - val_loss: 0.0122
#
# Epoch 00006: val_loss did not improve from 0.01215
# Epoch 7/100
#  - 4s - loss: 0.0062 - val_loss: 0.0122
#
# Epoch 00007: val_loss did not improve from 0.01215
# Epoch 8/100
#  - 4s - loss: 0.0063 - val_loss: 0.0121
#
# Epoch 00008: val_loss improved from 0.01215 to 0.01210, saving model to output/best_model.h5
# Epoch 9/100
#  - 4s - loss: 0.0062 - val_loss: 0.0121
#
# Epoch 00009: val_loss did not improve from 0.01210
# Epoch 10/100
#  - 4s - loss: 0.0062 - val_loss: 0.0121
#
# Epoch 00010: val_loss improved from 0.01210 to 0.01208, saving model to output/best_model.h5
# Epoch 11/100
#  - 4s - loss: 0.0065 - val_loss: 0.0121
#
# Epoch 00011: val_loss did not improve from 0.01208
# Epoch 12/100
#  - 4s - loss: 0.0062 - val_loss: 0.0121
#
# Epoch 00012: val_loss improved from 0.01208 to 0.01207, saving model to output/best_model.h5
# Epoch 13/100
#  - 4s - loss: 0.0062 - val_loss: 0.0121
#
# Epoch 00013: val_loss did not improve from 0.01207
# Epoch 14/100
#  - 4s - loss: 0.0060 - val_loss: 0.0121
#
# Epoch 00014: val_loss did not improve from 0.01207
# Epoch 15/100
#  - 4s - loss: 0.0062 - val_loss: 0.0121
#
# Epoch 00015: val_loss did not improve from 0.01207
# Epoch 16/100
#  - 4s - loss: 0.0060 - val_loss: 0.0121
#
# Epoch 00016: val_loss did not improve from 0.01207
# Epoch 17/100
#  - 4s - loss: 0.0062 - val_loss: 0.0121
#
# Epoch 00017: val_loss did not improve from 0.01207
# Epoch 18/100
#  - 4s - loss: 0.0060 - val_loss: 0.0121
#
# Epoch 00018: val_loss did not improve from 0.01207
# Epoch 19/100
#  - 4s - loss: 0.0060 - val_loss: 0.0121
#
# Epoch 00019: val_loss improved from 0.01207 to 0.01207, saving model to output/best_model.h5
# Epoch 20/100
#  - 4s - loss: 0.0062 - val_loss: 0.0121
#
# Epoch 00020: val_loss did not improve from 0.01207
# Epoch 21/100
#  - 4s - loss: 0.0060 - val_loss: 0.0122
#
# Epoch 00021: val_loss did not improve from 0.01207
# Epoch 22/100
#  - 4s - loss: 0.0062 - val_loss: 0.0121
#
# Epoch 00022: val_loss did not improve from 0.01207
# Epoch 23/100
#  - 4s - loss: 0.0061 - val_loss: 0.0121
#
# Epoch 00023: val_loss did not improve from 0.01207
# Epoch 24/100
#  - 4s - loss: 0.0062 - val_loss: 0.0121
#
# Epoch 00024: val_loss did not improve from 0.01207
# Epoch 25/100
#  - 4s - loss: 0.0060 - val_loss: 0.0122
#
# Epoch 00025: val_loss did not improve from 0.01207
# Epoch 26/100
#  - 4s - loss: 0.0056 - val_loss: 0.0122
#
# Epoch 00026: val_loss did not improve from 0.01207
# Epoch 27/100
#  - 4s - loss: 0.0055 - val_loss: 0.0122
#
# Epoch 00027: val_loss did not improve from 0.01207
# Epoch 28/100
#  - 4s - loss: 0.0061 - val_loss: 0.0122
#
# Epoch 00028: val_loss did not improve from 0.01207
# Epoch 29/100
#  - 4s - loss: 0.0058 - val_loss: 0.0123
#
# Epoch 00029: val_loss did not improve from 0.01207
# Epoch 30/100
#  - 4s - loss: 0.0057 - val_loss: 0.0125
#
# Epoch 00030: val_loss did not improve from 0.01207
# Epoch 31/100
#  - 4s - loss: 0.0059 - val_loss: 0.0124
#
# Epoch 00031: val_loss did not improve from 0.01207
# Epoch 32/100
#  - 4s - loss: 0.0057 - val_loss: 0.0124
#
# Epoch 00032: val_loss did not improve from 0.01207
# Epoch 33/100
#  - 4s - loss: 0.0058 - val_loss: 0.0124
#
# Epoch 00033: val_loss did not improve from 0.01207
# Epoch 34/100
#  - 4s - loss: 0.0059 - val_loss: 0.0122
#
# Epoch 00034: val_loss did not improve from 0.01207
# Epoch 35/100
#  - 4s - loss: 0.0056 - val_loss: 0.0122
#
# Epoch 00035: val_loss did not improve from 0.01207
# Epoch 36/100
#  - 4s - loss: 0.0057 - val_loss: 0.0122
#
# Epoch 00036: val_loss did not improve from 0.01207
# Epoch 37/100
#  - 4s - loss: 0.0058 - val_loss: 0.0128
#
# Epoch 00037: val_loss did not improve from 0.01207
# Epoch 38/100
#  - 4s - loss: 0.0058 - val_loss: 0.0122
#
# Epoch 00038: val_loss did not improve from 0.01207
# Epoch 39/100
#  - 4s - loss: 0.0054 - val_loss: 0.0124
#
# Epoch 00039: val_loss did not improve from 0.01207
# Epoch 40/100
#  - 4s - loss: 0.0056 - val_loss: 0.0123
#
# Epoch 00040: val_loss did not improve from 0.01207
# Epoch 41/100
#  - 4s - loss: 0.0055 - val_loss: 0.0121
#
# Epoch 00041: val_loss did not improve from 0.01207
# Epoch 00041: early stopping
# saving model...

# %% [markdown]
# ### Model Evaluation

# %%
plt.figure(figsize=(15,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
#plt.show()
plt.savefig(os.path.join(OUTPUT_PATH, 'train_vs_val_'+str(BATCH_SIZE)+'.png'))

# %% [markdown]
# ### Model Testing

# %%
# load the saved best model from above
saved_model = load_model(os.path.join(OUTPUT_PATH, 'best_model.h5'))
print(saved_model)

y_pred = saved_model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
# Out:
# <keras.engine.sequential.Sequential object at 0x7f9786e83908>
# Error is 0.002365450322774397 (40,) (40,)

# %%
y_pred_org = (y_pred * min_max_scaler.data_range_[10]) + min_max_scaler.data_min_[10] # min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[10]) + min_max_scaler.data_min_[10] # min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])

plt.figure(figsize=(15,10))
plt.plot(y_pred_org)
plt.plot(y_test_t_org)
plt.title('Prediction vs Real PM2.5 values')
plt.ylabel('PM 2.5')
plt.xlabel('Days')
plt.legend(['Prediction', 'Real'], loc='upper left')
#plt.show()
plt.savefig(os.path.join(OUTPUT_PATH, 'pred_vs_real_PM25'+str(BATCH_SIZE)+'.png'))
# Out:
# [81.70801  81.87431  82.044    82.288925 82.47437  82.55687  82.62924
#  82.9121   83.10314  83.234116 81.8101   81.93143  82.45316  82.62985
#  82.816505]
# [42.76 57.82 92.03 62.89 61.54 40.54 56.42 91.76 51.47 76.57 77.09 33.32
#  87.59 73.63 90.28]

# %% [markdown]
# # Do It Yourself
#
# But how do you land on the perfect (or in almost all the cases, close to perfect) architecture for your neural network? How do you decide the values for each of the hyper-parameters? Refer to the following link for additional information: [**How to Find the Right Architecture for Neural Network and Fine Tune Hyperparameters**](https://towardsdatascience.com/finding-the-right-architecture-for-neural-network-b0439efa4587)
